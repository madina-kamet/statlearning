# %% [markdown]
# <a href="https://colab.research.google.com/github/madina-kamet/statlearning/blob/main/LogisticRegressionFinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import load_digits, load_breast_cancer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from matplotlib import pyplot
from sklearn.metrics import accuracy_score
plt.rcParams['figure.figsize'] = [15, 5]

# %%
data = load_breast_cancer()

# # Import pandas
# import pandas as pd
# # Read the DataFrame, first using the feature data
# df = pd.DataFrame(data.data, columns=data.feature_names)
# # Add a target column, and fill it with the target data
# df['target'] = data.target
# # Show the first five rows
# df.head()


# Store the feature data
X = data.data
# store the target data
y = data.target
# split the data using Scikit-Learn's train_test_split
from sklearn.model_selection import train_test_split




test_score_array = []
train_score_array = []



for d in range(26):
  
  x_local = X[:, d:]

  x_train, x_test, y_train, y_test = train_test_split(x_local, y, train_size=0.7)

  model = LogisticRegression(max_iter=10000000000)
  model.fit(x_train, y_train)

  y_pred_test = model.predict(x_test)


  train_score_array.append(model.score(x_train, y_train))

  test_score_array.append(accuracy_score (y_test, y_pred_test))
  if(d in [0, 10, 20, 25]):
    print('___________________________________________________________')
    print()
    print('Train for %s: %.3f '% (30-d, model.score(x_train, y_train)))
    print('Test for %s: %.3f ' % (30-d, accuracy_score (y_test, y_pred_test)))
    print()


plt.subplot(1, 2, 1)
plt.plot(test_score_array)
plt.title("Test score Array")




plt.subplot(1, 2, 2)
plt.plot(train_score_array)
plt.title("Train score Array")


plt.show()
# Out:
# ___________________________________________________________
#
# Train for 30: 0.950
# Test for 30: 0.971
#
# ___________________________________________________________
#
# Train for 20: 0.945
# Test for 20: 0.953
#
# ___________________________________________________________
#
# Train for 10: 0.952
# Test for 10: 0.959
#
# ___________________________________________________________
#
# Train for 5: 0.859
# Test for 5: 0.848

# %%
data = load_breast_cancer()

# # Import pandas
# import pandas as pd
# # Read the DataFrame, first using the feature data
# df = pd.DataFrame(data.data, columns=data.feature_names)
# # Add a target column, and fill it with the target data
# df['target'] = data.target
# # Show the first five rows
# df.head()


# Store the feature data
X = data.data
# store the target data
y = data.target
# split the data using Scikit-Learn's train_test_split
from sklearn.model_selection import train_test_split




test_score_array = []
train_score_array = []



for m in range(1,10):
  
  x_local = X[:, :]

  x_train, x_test, y_train, y_test = train_test_split(x_local, y, train_size=0.1*m)

  model = LogisticRegression(max_iter=10000000000)
  model.fit(x_train, y_train)

  y_pred_test = model.predict(x_test)


  train_score_array.append(model.score(x_train, y_train))

  test_score_array.append(accuracy_score (y_test, y_pred_test))
  print('___________________________________________________________')
  print()
  print('Train for %.1f: %.3f '% (0.1*m, model.score(x_train, y_train)))
  print('Test for %.1f: %.3f ' % (1-0.1*m, accuracy_score (y_test, y_pred_test)))
  print()


plt.subplot(1, 2, 1)
plt.plot(test_score_array)
plt.title("Test score Array")




plt.subplot(1, 2, 2)
plt.plot(train_score_array)
plt.title("Train score Array")


plt.show()
# Out:
# ___________________________________________________________
#
# Train for 0.1: 1.000
# Test for 0.9: 0.912
#
# ___________________________________________________________
#
# Train for 0.2: 0.973
# Test for 0.8: 0.934
#
# ___________________________________________________________
#
# Train for 0.3: 0.982
# Test for 0.7: 0.950
#
# ___________________________________________________________
#
# Train for 0.4: 0.960
# Test for 0.6: 0.953
#
# ___________________________________________________________
#
# Train for 0.5: 0.965
# Test for 0.5: 0.944
#
# ___________________________________________________________
#
# Train for 0.6: 0.968
# Test for 0.4: 0.943
#
# ___________________________________________________________
#
# Train for 0.7: 0.957
# Test for 0.3: 0.965
#
# ___________________________________________________________
#
# Train for 0.8: 0.954
# Test for 0.2: 0.965
#
# ___________________________________________________________
#
# Train for 0.9: 0.951
# Test for 0.1: 1.000

# %%
data = load_breast_cancer()

# # Import pandas
# import pandas as pd
# # Read the DataFrame, first using the feature data
# df = pd.DataFrame(data.data, columns=data.feature_names)
# # Add a target column, and fill it with the target data
# df['target'] = data.target
# # Show the first five rows
# df.head()


# Store the feature data
X = data.data
# store the target data
y = data.target
# split the data using Scikit-Learn's train_test_split
from sklearn.model_selection import train_test_split




test_score_array = []
train_score_array = []


m_arr = []
m_times_test_err = []
for m in range(1,10):
  
  x_local = X[:, :]
  x_train, x_test, y_train, y_test = train_test_split(x_local, y, train_size=0.1*m)
  m_real = x_train.shape[0]

  model = LogisticRegression(max_iter=10000000000)
  model.fit(x_train, y_train)
  y_pred_test = model.predict(x_test)
  m_arr.append(m)
  train_score_array.append(model.score(x_train, y_train))

  test_score_array.append((1-accuracy_score (y_test, y_pred_test)))
  m_times_test_err.append(((1-accuracy_score (y_test, y_pred_test))*m_real))

plt.subplot(1, 2, 1)
plt.plot(test_score_array)
plt.title("Test error")




plt.subplot(1, 2, 2)
plt.plot(m_times_test_err)
plt.title("M X test error")
# Out:
# Text(0.5, 1.0, 'M X test error')

# %%
data = load_breast_cancer()

# # Import pandas
# import pandas as pd
# # Read the DataFrame, first using the feature data
# df = pd.DataFrame(data.data, columns=data.feature_names)
# # Add a target column, and fill it with the target data
# df['target'] = data.target
# # Show the first five rows
# df.head()


# Store the feature data
X = data.data
# store the target data
y = data.target
# split the data using Scikit-Learn's train_test_split
from sklearn.model_selection import train_test_split

from math import log, log10, exp, e, pow, sqrt


test_score_array = []
train_score_array = []


m_arr = []
m_times_test_err = []
error_bound = []
for m in range(1,10):
  
  x_local = X[:, :]
  x_train, x_test, y_train, y_test = train_test_split(x_local, y, train_size=0.1*m)
  m_real = x_train.shape[0]

  model = LogisticRegression(max_iter=10000000000)
  model.fit(x_train, y_train)
  y_pred_test = model.predict(x_test)
  m_arr.append(m_real)
  train_score_array.append(model.score(x_train, y_train))
  error_bound.append(30+log10(1/0.95))
  test_score_array.append((1-accuracy_score (y_test, y_pred_test))*100)
  m_times_test_err.append(((1-accuracy_score (y_test, y_pred_test))*m_real))


plt.plot(m_arr, error_bound, label='error')
plt.scatter(m_arr, m_times_test_err, label='m x error')
plt.title("M X test error")


plt.show()

# %%
data = load_breast_cancer()

# # Import pandas
# import pandas as pd
# # Read the DataFrame, first using the feature data
# df = pd.DataFrame(data.data, columns=data.feature_names)
# # Add a target column, and fill it with the target data
# df['target'] = data.target
# # Show the first five rows
# df.head()


# Store the feature data
X = data.data
# store the target data
y = data.target
# split the data using Scikit-Learn's train_test_split
from sklearn.model_selection import train_test_split

from math import log, log10, exp, e, pow, sqrt


test_score_array = []
train_score_array = []


m_arr = []
m_times_test_err = []
error_bound = []
for m in range(1,10):
  
  x_local = X[:, 10:]
  x_train, x_test, y_train, y_test = train_test_split(x_local, y, train_size=0.1*m)
  m_real = x_train.shape[0]

  model = LogisticRegression(max_iter=10000000000)
  model.fit(x_train, y_train)
  y_pred_test = model.predict(x_test)
  m_arr.append(m_real)
  train_score_array.append(model.score(x_train, y_train))
  error_bound.append(20+log10(1/0.95))
  test_score_array.append((1-accuracy_score (y_test, y_pred_test))*100)
  m_times_test_err.append(((1-accuracy_score (y_test, y_pred_test))*m_real))


plt.plot(m_arr, error_bound, label='error')
plt.scatter(m_arr, m_times_test_err, label='m x error')
plt.title("M X test error")


plt.show()

# %%
data = load_breast_cancer()

# # Import pandas
# import pandas as pd
# # Read the DataFrame, first using the feature data
# df = pd.DataFrame(data.data, columns=data.feature_names)
# # Add a target column, and fill it with the target data
# df['target'] = data.target
# # Show the first five rows
# df.head()


# Store the feature data
X = data.data
# store the target data
y = data.target
# split the data using Scikit-Learn's train_test_split
from sklearn.model_selection import train_test_split

from math import log, log10, exp, e, pow, sqrt


test_score_array = []
train_score_array = []


m_arr = []
m_times_test_err = []
error_bound = []
for d in range(1,30):
  
  x_local = X[:, d:]
  x_train, x_test, y_train, y_test = train_test_split(x_local, y, train_size=0.7)
  m_real = x_train.shape[0]

  model = LogisticRegression(max_iter=10000000000)
  model.fit(x_train, y_train)
  y_pred_test = model.predict(x_test)
  m_arr.append(d)
  train_score_array.append(model.score(x_train, y_train))
  error_bound.append((30-d)+log10(1/0.95))
  m_times_test_err.append(((1-accuracy_score (y_test, y_pred_test))/d))


plt.plot(m_arr, error_bound, label='error')
plt.scatter(m_arr, m_times_test_err, label='m x error')
plt.title("M X test error")


plt.show()
